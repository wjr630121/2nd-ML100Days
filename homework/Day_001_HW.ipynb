# %% [markdown]
# ## 作業 - 1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 挑選的資料集：House Prices: Advanced Regression Techniques
#
# 1. 你選的這組資料為何重要：藉由分析可得知影響地區房價的相關因素與指標
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：KAGGLE競賽
#
# 3. 蒐集而來的資料型態為何：80個FEATURE，訓練集與測試集各約有近1500筆資料
#
# 4. 這組資料想解決的問題如何評估：分析各項FEATURE，找出房價預測模型，並進行房價預測

# %% [markdown]
# ## 作業 - 2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：
#
#     A. 提升業績代表增加載客率 & 公司整體營業額
#
#     B. 影響顧客選擇搭乘因素
#         1. 硬體：車輛新舊年份、車輛廠牌、車輛舒適度
#         2. 軟體：服務態度(顧客意見調查)、顧客等待時間、
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：網路評價、意見調查表、系統紀錄
#
# 3. 蒐集而來的資料型態為何：文字、DATA
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：月均(周均)營業額報表

# %% [markdown]
# ## 作業3：練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    sumMSE = []
    for i in range(len(y)):
        num = (y[i] - y_hat[i]) **2
        sumMSE.append(num)
        
    MSE = sum(sumMSE) / len(y)
    return MSE

def mean_absolute_error(y, y_hat):
    sumMAE = []
    for i in range(len(y)):
        num = abs(y[i] - y_hat[i])
        sumMAE.append(num)
        
    MAE = sum(sumMAE) / len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.566
# The Mean absolute error is 12.069
